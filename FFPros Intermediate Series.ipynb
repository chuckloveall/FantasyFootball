# %%
import pandas as pd #import pandas in to our code so we can use it
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

csv_path = '2019.csv' #our file path is just our file name

df = pd.read_csv(csv_path) #load our CSV in to a DataFrame using read_csv

df.drop(['Fumbles','FumblesLost', 'GS'], axis=1, inplace=True)
df.rename({
'TD': 'PassingTD',
'TD.1': 'RushingTD',
'TD.2': 'ReceivingTD',
'TD.3': 'TotalTD',
'Yds': 'PassingYDs',
'Yds.1': 'RushingYDs',
'Yds.2': 'ReceivingYDs',
'Att': 'PassingAtt',
'Att.1': 'RushingAtt'
}, axis=1, inplace=True)
df['Player'] = df['Player'].apply(lambda x: x.split('*')[0]).apply(lambda x: x.split('\\')[0])
rb_df = df[df['Pos'] == 'RB']
qb_df = df[df['Pos'] == 'QB']
wr_df = df[df['Pos'] == 'WR']
te_df = df[df['Pos'] == 'TE']
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    Unnamed: 0               Player   Tm Pos   Age     G    Cmp  PassingAtt  \
# 0           0  Christian McCaffrey  CAR  RB  23.0  16.0    0.0         2.0
# 1           1        Lamar Jackson  BAL  QB  22.0  15.0  265.0       401.0
# 2           2        Derrick Henry  TEN  RB  25.0  15.0    0.0         0.0
# 3           3          Aaron Jones  GNB  RB  25.0  16.0    0.0         0.0
# 4           4      Ezekiel Elliott  DAL  RB  24.0  16.0    0.0         0.0
#
#    PassingYDs  Int  RushingAtt  RushingYDs    Tgt    Rec  ReceivingYDs    Y/R  \
# 0         0.0  0.0       287.0      1387.0  142.0  116.0        1005.0   8.66
# 1      3127.0  6.0       176.0      1206.0    0.0    0.0           0.0   0.00
# 2         0.0  0.0       303.0      1540.0   24.0   18.0         206.0  11.44
# 3         0.0  0.0       236.0      1084.0   68.0   49.0         474.0   9.67
# 4         0.0  0.0       301.0      1357.0   71.0   54.0         420.0   7.78
#
# ...

# %%
#rushing_columns=['RushingAtt', 'RushingYDS', 'RushingTD']
#receiving_columns= ['Rec', 'ReceivingYDS', 'Y/R','ReceivingTD', 'Tgt']
#passing_columns= ['PassingAtt', 'PassingYDS', 'Int', 'Cmp']
#def transform_columns(df, new_column_list):
    #df= df[['Player','Tm','Age','G']+ new_column_list]
    #return df

# %%
#rb_df= transform_columns(rb_df, rushing_columns+receiving_columns)
#wr_df= transform_columns(wr_df, rushing_columns+receiving_columns)
#te_df= transform_columns(te_df, receiving_columns)
#qb_df= transform_columns(qb_df, passing_columns)
#rb_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-fa499af2c066> in <module>
# ----> 1 rb_df= transform_columns(rb_df, rushing_columns+receiving_columns)
#       2 wr_df= transform_columns(wr_df, rushing_columns+receiving_columns)
#       3 te_df= transform_columns(te_df, receiving_columns)
#       4 qb_df= transform_columns(qb_df, passing_columns)
#       5 rb_df.head()
#
# <ipython-input-10-10994cb8c39f> in transform_columns(df, new_column_list)
#       3 passing_columns= ['PassingAtt', 'PassingYDS', 'Int', 'Cmp']
#       4 def transform_columns(df,new_column_list):
# ----> 5     df=df[['Player','Tm','Age','G']+ new_column_list]
#       6     return df
#
# TypeError: list indices must be integers or slices, not list
